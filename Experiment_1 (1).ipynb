# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# %%
df = pd.read_csv("/content/student-mat.csv",sep=';')

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

# %%
X = df.drop("G3", axis=1)
Y = df["G3"]

# %%
print(df.dtypes)
# Out:
# school        int64
# sex           int64
# age           int64
# address       int64
# famsize       int64
# Pstatus       int64
# Medu          int64
# Fedu          int64
# Mjob          int64
# Fjob          int64
# reason        int64
# guardian      int64
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup     int64
# famsup        int64
# paid          int64
# activities    int64
# nursery       int64
# higher        int64
# internet      int64
# romantic      int64
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
print(df.isnull().sum())
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df = df.dropna()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# Build ANN Model
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

# Compile Model
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# Model Summary
model.summary()

# Train Model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)

# Evaluate Model
loss, mae = model.evaluate(X_test, Y_test)

print("\nTest MAE:", mae)

# Predict First 5 Students
predictions = model.predict(X_test[:5])

for i in range(5):
    print(f"Actual Grade: {Y_test.iloc[i]}")
    print(f"Predicted Grade: {predictions[i][0]:.2f}")
    print("-" * 30)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,225 (16.50 KB)
#  Trainable params: 4,225 (16.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 111.0932 - mae: 9.5939 - val_loss: 103.2726 - val_mae: 9.4998
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 99.8406 - mae: 9.1129 - val_loss: 92.1143 - val_mae: 8.9843
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 88.3730 - mae: 8.5903 - val_loss: 80.0108 - val_mae: 8.3794
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 75.8236 - mae: 7.9783 - val_loss: 66.8840 - val_mae: 7.6633
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 62.3220 - mae: 7.2236 - val_loss: 53.1927 - val_mae: 6.8292
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 48.1932 - mae: 6.3426 - val_loss: 39.9595 - val_mae: 5.9242
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 35.2089 - mae: 5.3853 - val_loss: 28.1181 - val_mae: 4.9045
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.8623 - mae: 4.3497 - val_loss: 19.1041 - val_mae: 3.8724
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.5422 - mae: 3.3972 - val_loss: 13.5739 - val_mae: 3.0497
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 11.3174 - mae: 2.7308 - val_loss: 10.9850 - val_mae: 2.5139
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0741 - mae: 2.3385 - val_loss: 10.3456 - val_mae: 2.3394
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2019 - mae: 2.1814 - val_loss: 10.0448 - val_mae: 2.2898
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.4135 - mae: 2.0676 - val_loss: 9.6567 - val_mae: 2.2503
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7203 - mae: 1.9735 - val_loss: 9.2807 - val_mae: 2.2266
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1524 - mae: 1.8916 - val_loss: 9.0300 - val_mae: 2.2069
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7589 - mae: 1.8287 - val_loss: 8.8613 - val_mae: 2.1922
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4443 - mae: 1.7781 - val_loss: 8.7634 - val_mae: 2.1771
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1371 - mae: 1.7256 - val_loss: 8.6218 - val_mae: 2.1623
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9042 - mae: 1.6855 - val_loss: 8.4718 - val_mae: 2.1437
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7049 - mae: 1.6488 - val_loss: 8.3423 - val_mae: 2.1315
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4864 - mae: 1.6118 - val_loss: 8.2262 - val_mae: 2.1211
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3262 - mae: 1.5828 - val_loss: 8.1389 - val_mae: 2.1156
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1709 - mae: 1.5544 - val_loss: 8.1016 - val_mae: 2.1132
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0047 - mae: 1.5232 - val_loss: 8.0178 - val_mae: 2.1075
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8616 - mae: 1.4948 - val_loss: 7.9207 - val_mae: 2.0970
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7261 - mae: 1.4677 - val_loss: 7.8519 - val_mae: 2.0902
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6041 - mae: 1.4429 - val_loss: 7.8090 - val_mae: 2.0859
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4891 - mae: 1.4215 - val_loss: 7.7329 - val_mae: 2.0821
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3756 - mae: 1.3985 - val_loss: 7.6747 - val_mae: 2.0776
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2701 - mae: 1.3760 - val_loss: 7.6361 - val_mae: 2.0760
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1618 - mae: 1.3538 - val_loss: 7.5628 - val_mae: 2.0707
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0614 - mae: 1.3331 - val_loss: 7.5160 - val_mae: 2.0654
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9616 - mae: 1.3123 - val_loss: 7.4512 - val_mae: 2.0627
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8697 - mae: 1.2924 - val_loss: 7.3902 - val_mae: 2.0624
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7723 - mae: 1.2693 - val_loss: 7.3468 - val_mae: 2.0583
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6840 - mae: 1.2495 - val_loss: 7.2530 - val_mae: 2.0471
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5981 - mae: 1.2312 - val_loss: 7.2116 - val_mae: 2.0483
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5132 - mae: 1.2116 - val_loss: 7.1637 - val_mae: 2.0396
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4240 - mae: 1.1902 - val_loss: 7.0949 - val_mae: 2.0391
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3442 - mae: 1.1689 - val_loss: 7.0922 - val_mae: 2.0394
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2648 - mae: 1.1497 - val_loss: 7.0048 - val_mae: 2.0290
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1851 - mae: 1.1311 - val_loss: 6.9129 - val_mae: 2.0239
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0988 - mae: 1.1080 - val_loss: 6.8771 - val_mae: 2.0177
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0269 - mae: 1.0903 - val_loss: 6.8295 - val_mae: 2.0108
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9413 - mae: 1.0670 - val_loss: 6.7459 - val_mae: 2.0070
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8641 - mae: 1.0454 - val_loss: 6.7251 - val_mae: 2.0071
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7987 - mae: 1.0278 - val_loss: 6.6613 - val_mae: 1.9996
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7209 - mae: 1.0069 - val_loss: 6.5971 - val_mae: 1.9988
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6502 - mae: 0.9861 - val_loss: 6.5816 - val_mae: 1.9959
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5740 - mae: 0.9659 - val_loss: 6.5291 - val_mae: 1.9901
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.4578 - mae: 1.9276
#
# Test MAE: 1.9276269674301147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Actual Grade: 10
# Predicted Grade: 6.32
# ------------------------------
# Actual Grade: 12
# Predicted Grade: 11.04
# ------------------------------
# Actual Grade: 5
# Predicted Grade: 2.66
# ------------------------------
# Actual Grade: 10
# Predicted Grade: 8.30
# ------------------------------
# Actual Grade: 9
# Predicted Grade: 10.31
# ------------------------------
